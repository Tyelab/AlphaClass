# %%
import h5py
import numpy as np
import os
import json
import pandas as pd

# %%
data = r''
data = h5py.File(data, 'r')

with open(r'', 'r') as f:
    idx = json.load(f)
    
idx = dict((v,k) for k,v in idx.items())
idx
# Out:
# {0: 'F2F', 1: 'chasing', 2: 'lateral'}

# %%
points = data['points']
confs = data['confs']

# %%
first = points[1]

# %%
all_predictions = []
for point in points:
    point = np.stack(point)
    if point.shape[1] > 0:
        prediction = idx[point[:,0][1]]
        all_predictions.append(prediction)

    else:
        all_predictions.append('none')
# image index
# behavioral ID
# y
# x

# %%
all_predictions
# Out:
# ['chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'chasing',
#  'F2F',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
# ...

# %%
# Out:
# 'chasing'
